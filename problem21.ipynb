# %%
import math 
    
tab = []
i = 0

while i < 10000:
    tab.append(i)
    i=i+1
    
def divisors(n):
    summ = 0
    j=2
    while j<=math.sqrt(n):
        if(n%j==0):
            if(n/j!=j):
                summ=summ + j
                summ=summ + n/j
            else:
                summ=summ + j
        j = j +1
    return int(summ+1)
    
itera = 0
summ=0
for k in tab:
    if(divisors(divisors(k)) == k and divisors(k)!=divisors(divisors(k))):
        summ = k + divisors(k) + summ
        print(divisors(divisors(k)))
        print("lol")
        print(divisors(k))
        print("________")
        print(k)
        print("----------------")
        itera = itera +1
        
print(summ/2)
# Out:
# 220
# lol
# 284
# ________
# 220
# ----------------
# 284
# lol
# 220
# ________
# 284
# ----------------
# 1184
# lol
# 1210
# ________
# 1184
# ----------------
# 1210
# lol
# 1184
# ________
# 1210
# ----------------
# 2620
# lol
# 2924
# ________
# 2620
# ----------------
# 2924
# lol
# 2620
# ________
# 2924
# ----------------
# 5020
# lol
# 5564
# ________
# 5020
# ----------------
# 5564
# lol
# 5020
# ________
# 5564
# ----------------
# 6232
# lol
# 6368
# ________
# 6232
# ----------------
# 6368
# lol
# 6232
# ________
# 6368
# ----------------
# 31626.0
